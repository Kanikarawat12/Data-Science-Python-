# %%
# !pip install pandas
# !pip install seaborn
# !pip install numpy
# !pip install matplotlib

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
df= pd.read_csv(r"C:\Users\karti\Downloads\WHO-COVID-19-global-data.csv")
df
# Out:
#        Date_reported Country_code      Country WHO_region  New_cases  \
# 0         2020-01-03           AF  Afghanistan       EMRO          0
# 1         2020-01-04           AF  Afghanistan       EMRO          0
# 2         2020-01-05           AF  Afghanistan       EMRO          0
# 3         2020-01-06           AF  Afghanistan       EMRO          0
# 4         2020-01-07           AF  Afghanistan       EMRO          0
# ...              ...          ...          ...        ...        ...
# 179404    2022-01-24           ZW     Zimbabwe       AFRO         75
# 179405    2022-01-25           ZW     Zimbabwe       AFRO        287
# 179406    2022-01-26           ZW     Zimbabwe       AFRO        235
# 179407    2022-01-27           ZW     Zimbabwe       AFRO        167
# 179408    2022-01-28           ZW     Zimbabwe       AFRO        153
#
#         Cumulative_cases  New_deaths  Cumulative_deaths
# 0                      0           0                  0
# ...

# %%
df.describe()
# Out:
#           New_cases  Cumulative_cases     New_deaths  Cumulative_deaths
# count  1.794090e+05      1.794090e+05  179409.000000      179409.000000
# mean   2.029951e+03      4.645195e+05      31.388933       10046.316277
# std    1.473019e+04      2.570289e+06     164.820223       48103.870690
# min   -3.295200e+04      0.000000e+00     -92.000000           0.000000
# 25%    0.000000e+00      1.090000e+02       0.000000           1.000000
# 50%    2.000000e+01      7.638000e+03       0.000000         114.000000
# 75%    4.620000e+02      1.253110e+05       6.000000        2131.000000
# max    1.326265e+06      7.237337e+07    8786.000000      869779.000000

# %%
#visualization

# %%
df.isnull().sum()
# Out:
# Date_reported          0
# Country_code         757
# Country                0
# WHO_region             0
# New_cases              0
# Cumulative_cases       0
# New_deaths             0
# Cumulative_deaths      0
# dtype: int64

# %%
#Let us not use the Country code table as we can neither delete nor use mean of it.

# %%
df['Month'] = df['Date_reported'].apply(lambda x: x.split('-')[1])
df
# Out:
#        Date_reported Country_code      Country WHO_region  New_cases  \
# 0         2020-01-03           AF  Afghanistan       EMRO          0
# 1         2020-01-04           AF  Afghanistan       EMRO          0
# 2         2020-01-05           AF  Afghanistan       EMRO          0
# 3         2020-01-06           AF  Afghanistan       EMRO          0
# 4         2020-01-07           AF  Afghanistan       EMRO          0
# ...              ...          ...          ...        ...        ...
# 179404    2022-01-24           ZW     Zimbabwe       AFRO         75
# 179405    2022-01-25           ZW     Zimbabwe       AFRO        287
# 179406    2022-01-26           ZW     Zimbabwe       AFRO        235
# 179407    2022-01-27           ZW     Zimbabwe       AFRO        167
# 179408    2022-01-28           ZW     Zimbabwe       AFRO        153
#
#         Cumulative_cases  New_deaths  Cumulative_deaths Month
# 0                      0           0                  0    01
# ...

# %%
df['Year'] = df['Date_reported'].apply(lambda x: x.split('-')[0])
df
# Out:
#        Date_reported Country_code      Country WHO_region  New_cases  \
# 0         2020-01-03           AF  Afghanistan       EMRO          0
# 1         2020-01-04           AF  Afghanistan       EMRO          0
# 2         2020-01-05           AF  Afghanistan       EMRO          0
# 3         2020-01-06           AF  Afghanistan       EMRO          0
# 4         2020-01-07           AF  Afghanistan       EMRO          0
# ...              ...          ...          ...        ...        ...
# 179404    2022-01-24           ZW     Zimbabwe       AFRO         75
# 179405    2022-01-25           ZW     Zimbabwe       AFRO        287
# 179406    2022-01-26           ZW     Zimbabwe       AFRO        235
# 179407    2022-01-27           ZW     Zimbabwe       AFRO        167
# 179408    2022-01-28           ZW     Zimbabwe       AFRO        153
#
#         Cumulative_cases  New_deaths  Cumulative_deaths Month  Year
# 0                      0           0                  0    01  2020
# ...

# %%
pd.to_numeric(df['Month'])
df
# Out:
#        Date_reported Country_code      Country WHO_region  New_cases  \
# 0         2020-01-03           AF  Afghanistan       EMRO          0
# 1         2020-01-04           AF  Afghanistan       EMRO          0
# 2         2020-01-05           AF  Afghanistan       EMRO          0
# 3         2020-01-06           AF  Afghanistan       EMRO          0
# 4         2020-01-07           AF  Afghanistan       EMRO          0
# ...              ...          ...          ...        ...        ...
# 179404    2022-01-24           ZW     Zimbabwe       AFRO         75
# 179405    2022-01-25           ZW     Zimbabwe       AFRO        287
# 179406    2022-01-26           ZW     Zimbabwe       AFRO        235
# 179407    2022-01-27           ZW     Zimbabwe       AFRO        167
# 179408    2022-01-28           ZW     Zimbabwe       AFRO        153
#
#         Cumulative_cases  New_deaths  Cumulative_deaths Month  Year
# 0                      0           0                  0    01  2020
# ...

# %%
pd.to_numeric(df['Year'])
# Out:
# 0         2020
# 1         2020
# 2         2020
# 3         2020
# 4         2020
#           ...
# 179404    2022
# 179405    2022
# 179406    2022
# 179407    2022
# 179408    2022
# Name: Year, Length: 179409, dtype: int64

# %% [markdown]
# ### IN THIS ANALYSIS WE'LL CHECK INCREASE IN CASES AND DEATHS OF COVID PATIENTS IN AFGANISTAN FOR THE THREE CONSECUTIVE YEAR

# %%
df
# Out:
#        Date_reported Country_code      Country WHO_region  New_cases  \
# 0         2020-01-03           AF  Afghanistan       EMRO          0
# 1         2020-01-04           AF  Afghanistan       EMRO          0
# 2         2020-01-05           AF  Afghanistan       EMRO          0
# 3         2020-01-06           AF  Afghanistan       EMRO          0
# 4         2020-01-07           AF  Afghanistan       EMRO          0
# ...              ...          ...          ...        ...        ...
# 179404    2022-01-24           ZW     Zimbabwe       AFRO         75
# 179405    2022-01-25           ZW     Zimbabwe       AFRO        287
# 179406    2022-01-26           ZW     Zimbabwe       AFRO        235
# 179407    2022-01-27           ZW     Zimbabwe       AFRO        167
# 179408    2022-01-28           ZW     Zimbabwe       AFRO        153
#
#         Cumulative_cases  New_deaths  Cumulative_deaths Month  Year
# 0                      0           0                  0    01  2020
# ...

# %%
df0=df.groupby('Year').sum()
df0
# Out:
#       New_cases  Cumulative_cases  New_deaths  Cumulative_deaths
# Year
# 2020   82737396        7636662351     1901797          236696502
# 2021  202950115       66683281567     3528906         1410968999
# 2022   78503983        9019033040      200754          154734056

# %%
# If we look at this 2021 has maximum no of cases and death. But we should also notice that in 2022 we only have data for the month of January.

# %% [markdown]
# ### We will make separate subsets of cases in January month of 2020, 2021 and 2022.

# %%
df_jan2020=df.loc[0:28]
df_jan2020
# Out:
#    Date_reported Country_code      Country WHO_region  New_cases  \
# 0     2020-01-03           AF  Afghanistan       EMRO          0
# 1     2020-01-04           AF  Afghanistan       EMRO          0
# 2     2020-01-05           AF  Afghanistan       EMRO          0
# 3     2020-01-06           AF  Afghanistan       EMRO          0
# 4     2020-01-07           AF  Afghanistan       EMRO          0
# 5     2020-01-08           AF  Afghanistan       EMRO          0
# 6     2020-01-09           AF  Afghanistan       EMRO          0
# 7     2020-01-10           AF  Afghanistan       EMRO          0
# 8     2020-01-11           AF  Afghanistan       EMRO          0
# 9     2020-01-12           AF  Afghanistan       EMRO          0
# 10    2020-01-13           AF  Afghanistan       EMRO          0
# 11    2020-01-14           AF  Afghanistan       EMRO          0
# 12    2020-01-15           AF  Afghanistan       EMRO          0
# ...

# %%
df_jan2021 = df.loc[364:394]
df_jan2021
# Out:
#     Date_reported Country_code      Country WHO_region  New_cases  \
# 364    2021-01-01           AF  Afghanistan       EMRO        183
# 365    2021-01-02           AF  Afghanistan       EMRO         73
# 366    2021-01-03           AF  Afghanistan       EMRO        123
# 367    2021-01-04           AF  Afghanistan       EMRO        200
# 368    2021-01-05           AF  Afghanistan       EMRO        102
# 369    2021-01-06           AF  Afghanistan       EMRO         94
# 370    2021-01-07           AF  Afghanistan       EMRO        102
# 371    2021-01-08           AF  Afghanistan       EMRO        125
# 372    2021-01-09           AF  Afghanistan       EMRO         68
# 373    2021-01-10           AF  Afghanistan       EMRO         89
# 374    2021-01-11           AF  Afghanistan       EMRO         49
# 375    2021-01-12           AF  Afghanistan       EMRO         46
# 376    2021-01-13           AF  Afghanistan       EMRO        106
# ...

# %%
df_jan2022=df[729:757]
df_jan2022
# Out:
#     Date_reported Country_code      Country WHO_region  New_cases  \
# 729    2022-01-01           AF  Afghanistan       EMRO          0
# 730    2022-01-02           AF  Afghanistan       EMRO         53
# 731    2022-01-03           AF  Afghanistan       EMRO         44
# 732    2022-01-04           AF  Afghanistan       EMRO         15
# 733    2022-01-05           AF  Afghanistan       EMRO         36
# 734    2022-01-06           AF  Afghanistan       EMRO         38
# 735    2022-01-07           AF  Afghanistan       EMRO         34
# 736    2022-01-08           AF  Afghanistan       EMRO         26
# 737    2022-01-09           AF  Afghanistan       EMRO         40
# 738    2022-01-10           AF  Afghanistan       EMRO         36
# 739    2022-01-11           AF  Afghanistan       EMRO         13
# 740    2022-01-12           AF  Afghanistan       EMRO         58
# 741    2022-01-13           AF  Afghanistan       EMRO         59
# ...

# %%
df_afgan = pd.concat([df_jan2020,df_jan2021,df_jan2022])
df_afgan
# Out:
#     Date_reported Country_code      Country WHO_region  New_cases  \
# 0      2020-01-03           AF  Afghanistan       EMRO          0
# 1      2020-01-04           AF  Afghanistan       EMRO          0
# 2      2020-01-05           AF  Afghanistan       EMRO          0
# 3      2020-01-06           AF  Afghanistan       EMRO          0
# 4      2020-01-07           AF  Afghanistan       EMRO          0
# ..            ...          ...          ...        ...        ...
# 752    2022-01-24           AF  Afghanistan       EMRO        134
# 753    2022-01-25           AF  Afghanistan       EMRO        214
# 754    2022-01-26           AF  Afghanistan       EMRO        356
# 755    2022-01-27           AF  Afghanistan       EMRO        456
# 756    2022-01-28           AF  Afghanistan       EMRO        301
#
#      Cumulative_cases  New_deaths  Cumulative_deaths Month  Year
# 0                   0           0                  0    01  2020
# ...

# %%
df_jan_yearly = df_afgan.groupby('Year').sum()
df_jan_yearly
# Out:
#       New_cases  Cumulative_cases  New_deaths  Cumulative_deaths
# Year
# 2020          0                 0           0                  0
# 2021       2693           1671259         211              71891
# 2022       2950           4448857          47             206579

# %% [markdown]
# ### LET US DRAW GRAPHS OF OBSERVATIONS

# %%
Year = [2020,2021,2022]
plt.plot(Year , df_jan_yearly['New_cases'])
plt.title('AFGANISTAN January Cases')
plt.xlabel('Year')
plt.ylabel('New_cases')
plt.show()

# %%
df_who_region= df.groupby('WHO_region').sum()
df_who_region
# Out:
#             New_cases  Cumulative_cases  New_deaths  Cumulative_deaths
# WHO_region
# AFRO          8037551        2052279805      163532           48565044
# AMRO        132400000       33167006516     2489629          864989752
# EMRO         18614606        5206601318      320498          103547480
# EURO        138839947       26753789751     1757462          541556965
# Other             764            532364          13               8929
# SEARO        51328032       13852759439      733767          210036600
# WPRO         14970594        2306007765      166556           33694787

# %%
WHO_Region = pd.unique(df['WHO_region'])
plt.plot(WHO_Region, df_who_region['New_cases'])
plt.title('Cases In WHO Region')
plt.xlabel('WHO REGION')
plt.ylabel('CASES')
plt.show()

# %% [markdown]
# ### Let's see Country Wise Cases

# %%
df_countrywise = df.groupby('Country').sum()
df_countrywise
# Out:
#                                                     New_cases  \
# Country
# Afghanistan                                            161009
# Albania                                                254126
# Algeria                                                245698
# American Samoa                                             18
# Andorra                                                 35028
# ...                                                       ...
# Wallis and Futuna                                         453
# Yemen                                                   10942
# Zambia                                                 304002
# Zimbabwe                                               229096
# occupied Palestinian territory, including east ...     504992
#
#                                                     Cumulative_cases  \
# Country
# Afghanistan                                                 52461073
# ...

# %%
# %matplotlib inline
Country = pd.unique(df['Country'])
plt.plot(Country, df_countrywise['New_cases'])
plt.xlabel('COUNTRY')
plt.ylabel('Cases')
plt.title('Country-wise Cases')
plt.show()
