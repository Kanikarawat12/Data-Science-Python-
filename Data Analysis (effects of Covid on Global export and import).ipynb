# %%
# !pip install pandas
# !pip install matplotlib 
# !pip install numpy

# %%
import pandas as pd
import matplotlib.pyplot as plt 
import numpy as np

# %%
df=pd.read_csv(r"C:\Users\karti\Downloads\effects-of-covid-19-on-trade-at-15-december-2021-provisional.csv")
df
# Out:
#         Direction  Year        Date    Weekday Country Commodity  \
# 0         Exports  2015  01/01/2015   Thursday     All       All
# 1         Exports  2015  02/01/2015     Friday     All       All
# 2         Exports  2015  03/01/2015   Saturday     All       All
# 3         Exports  2015  04/01/2015     Sunday     All       All
# 4         Exports  2015  05/01/2015     Monday     All       All
# ...           ...   ...         ...        ...     ...       ...
# 111433  Reimports  2021  11/12/2021   Saturday     All       All
# 111434  Reimports  2021  12/12/2021     Sunday     All       All
# 111435  Reimports  2021  13/12/2021     Monday     All       All
# 111436  Reimports  2021  14/12/2021    Tuesday     All       All
# 111437  Reimports  2021  15/12/2021  Wednesday     All       All
#
#        Transport_Mode Measure      Value  Cumulative
# 0                 All       $  104000000   104000000
# 1                 All       $   96000000   200000000
# ...

# %%
df.dtypes
# Out:
# Direction         object
# Year               int64
# Date              object
# Weekday           object
# Country           object
# Commodity         object
# Transport_Mode    object
# Measure           object
# Value              int64
# Cumulative         int64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 111438 entries, 0 to 111437
# Data columns (total 10 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   Direction       111438 non-null  object
#  1   Year            111438 non-null  int64
#  2   Date            111438 non-null  object
#  3   Weekday         111438 non-null  object
#  4   Country         111438 non-null  object
#  5   Commodity       111438 non-null  object
#  6   Transport_Mode  111438 non-null  object
#  7   Measure         111438 non-null  object
#  8   Value           111438 non-null  int64
#  9   Cumulative      111438 non-null  int64
# dtypes: int64(3), object(7)
# memory usage: 8.5+ MB

# %%
df["Measure"]=df['Measure'].astype('bool')

# %%
df["Measure"]= np.where(df["Measure"] == "True" , True  , False)

# %%
df
# Out:
#         Direction  Year        Date    Weekday Country Commodity  \
# 0         Exports  2015  01/01/2015   Thursday     All       All
# 1         Exports  2015  02/01/2015     Friday     All       All
# 2         Exports  2015  03/01/2015   Saturday     All       All
# 3         Exports  2015  04/01/2015     Sunday     All       All
# 4         Exports  2015  05/01/2015     Monday     All       All
# ...           ...   ...         ...        ...     ...       ...
# 111433  Reimports  2021  11/12/2021   Saturday     All       All
# 111434  Reimports  2021  12/12/2021     Sunday     All       All
# 111435  Reimports  2021  13/12/2021     Monday     All       All
# 111436  Reimports  2021  14/12/2021    Tuesday     All       All
# 111437  Reimports  2021  15/12/2021  Wednesday     All       All
#
#        Transport_Mode  Measure      Value  Cumulative
# 0                 All    False  104000000   104000000
# 1                 All    False   96000000   200000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 111438 entries, 0 to 111437
# Data columns (total 10 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   Direction       111438 non-null  object
#  1   Year            111438 non-null  int64
#  2   Date            111438 non-null  object
#  3   Weekday         111438 non-null  object
#  4   Country         111438 non-null  object
#  5   Commodity       111438 non-null  object
#  6   Transport_Mode  111438 non-null  object
#  7   Measure         111438 non-null  bool
#  8   Value           111438 non-null  int64
#  9   Cumulative      111438 non-null  int64
# dtypes: bool(1), int64(3), object(6)
# memory usage: 7.8+ MB

# %% [markdown]
# ### Which Year has Maximum Export and Import

# %%
df1=df.groupby('Year').sum()
df1
# Out:
#       Measure         Value      Cumulative
# Year
# 2015        0  408266052000  73528808754000
# 2016        0  403704143000  73589415681000
# 2017        0  444906007000  78796366714000
# 2018        0  483121678000  86380178521000
# 2019        0  499900924000  90304728425000
# 2020        0  478846545000  87335509776000
# 2021        0  519364048000  86673544129000

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7 entries, 2015 to 2021
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Measure     7 non-null      int64
#  1   Value       7 non-null      int64
#  2   Cumulative  7 non-null      int64
# dtypes: int64(3)
# memory usage: 224.0 bytes

# %%
# %matplotlib inline
Year = range(2015,2022)
plt.bar(Year,df1['Value'])
plt.xlabel('Year')
plt.ylabel('Import/Export')
plt.title('Year with Maximum Import/Export')
plt.show()

# %% [markdown]
# ### 2021 has Maximum Import and Export

# %% [markdown]
# ### Which month of 2021 has maximum export/import?

# %% [markdown]
# ### Add a Month Column

# %% [markdown]
# # lets use the .apply() method

# %%
df['Month'] = df['Date'].apply(lambda x: x.split('/')[1])
df
# Out:
#         Direction  Year        Date    Weekday Country Commodity  \
# 0         Exports  2015  01/01/2015   Thursday     All       All
# 1         Exports  2015  02/01/2015     Friday     All       All
# 2         Exports  2015  03/01/2015   Saturday     All       All
# 3         Exports  2015  04/01/2015     Sunday     All       All
# 4         Exports  2015  05/01/2015     Monday     All       All
# ...           ...   ...         ...        ...     ...       ...
# 111433  Reimports  2021  11/12/2021   Saturday     All       All
# 111434  Reimports  2021  12/12/2021     Sunday     All       All
# 111435  Reimports  2021  13/12/2021     Monday     All       All
# 111436  Reimports  2021  14/12/2021    Tuesday     All       All
# 111437  Reimports  2021  15/12/2021  Wednesday     All       All
#
#        Transport_Mode  Measure      Value  Cumulative Month
# 0                 All    False  104000000   104000000    01
# 1                 All    False   96000000   200000000    01
# ...

# %% [markdown]
# ### Now Make a Subset of 2021 Rows

# %%
df2021 = df[df['Year']>2020]
df2021
# Out:
#         Direction  Year        Date    Weekday Country Commodity  \
# 96095     Exports  2021  01/01/2021     Friday     All       All
# 96096     Exports  2021  02/01/2021   Saturday     All       All
# 96097     Exports  2021  03/01/2021     Sunday     All       All
# 96098     Exports  2021  04/01/2021     Monday     All       All
# 96099     Exports  2021  05/01/2021    Tuesday     All       All
# ...           ...   ...         ...        ...     ...       ...
# 111433  Reimports  2021  11/12/2021   Saturday     All       All
# 111434  Reimports  2021  12/12/2021     Sunday     All       All
# 111435  Reimports  2021  13/12/2021     Monday     All       All
# 111436  Reimports  2021  14/12/2021    Tuesday     All       All
# 111437  Reimports  2021  15/12/2021  Wednesday     All       All
#
#        Transport_Mode  Measure      Value  Cumulative Month
# 96095             All    False   85000000    85000000    01
# 96096             All    False  132000000   216000000    01
# ...

# %%
df_months = df2021.drop(['Year'] , axis = 1)
df_months
# Out:
#         Direction        Date    Weekday Country Commodity Transport_Mode  \
# 96095     Exports  01/01/2021     Friday     All       All            All
# 96096     Exports  02/01/2021   Saturday     All       All            All
# 96097     Exports  03/01/2021     Sunday     All       All            All
# 96098     Exports  04/01/2021     Monday     All       All            All
# 96099     Exports  05/01/2021    Tuesday     All       All            All
# ...           ...         ...        ...     ...       ...            ...
# 111433  Reimports  11/12/2021   Saturday     All       All            All
# 111434  Reimports  12/12/2021     Sunday     All       All            All
# 111435  Reimports  13/12/2021     Monday     All       All            All
# 111436  Reimports  14/12/2021    Tuesday     All       All            All
# 111437  Reimports  15/12/2021  Wednesday     All       All            All
#
#         Measure      Value  Cumulative Month
# ...

# %%
df_2021 = df_months.groupby('Month').sum()
df_2021
# Out:
#        Measure        Value      Cumulative
# Month
# 01           0  36816505000    543131586000
# 02           0  36316355000   1558550956000
# 03           0  46659039000   3017645346000
# 04           0  42542652000   4258222561000
# 05           0  46703805000   5779327038000
# 06           0  48173793000   7007780350000
# 07           0  48679012000   8715657091000
# 08           0  42686040000  10161925556000
# 09           0  43359969000  11123804501000
# 10           0  48281505000  12914760657000
# 11           0  51493153000  13995030221000
# 12           0  27652220000   7597708266000

# %%
# %matplotlib notebook
Months = range(1,13)
plt.bar(Months, df_2021['Value'])
plt.xlabel('Month')
plt.ylabel('Import/Export')
plt.title('Import/Export in 2021')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="432">

# %% [markdown]
# ### November has maximum import/export

# %% [markdown]
# ### December has minimum import/export
